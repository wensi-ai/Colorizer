# %%
import os, sys
import cv2
import numpy as np
sys.path.append("../")
from utils.v2i import convert_video_to_frames, convert_frames_to_video

# %% [markdown]
# ## PreReqs
# > This algorithm requires both the original black and white video and the frame-wise colorized video. Turn both videos into frames.

# %%
ORIGINAL_PATH = "../test/frames"        # original black and white frames
PROCESSED_PATH = "../test/result"       # colorized frames
OUTPUT_PATH = "../test/consistent"
EPOCHS = 30

# %% [markdown]
# ## Reshape Everything

# %%
from PIL import Image

original_frames = os.listdir(ORIGINAL_PATH)
SHAPE = (320, 180)
SAVE_FREQ = 2

for each in original_frames:
    img = Image.open(os.path.join('../test/frames', each))
    img = img.resize(SHAPE, Image.ANTIALIAS)
    img.save(os.path.join('../test/frames', each))

# %%
# !python3 ../models/DVP/main_IRT.py --save_freq $SAVE_FREQ --max_epoch $EPOCHS --input $ORIGINAL_PATH --processed $PROCESSED_PATH --model colorization --with_IRT 1 --IRT_initialization 1 --output $OUTPUT_PATH
# Out:
# Namespace(model='colorization', save_freq=2, use_gpu=1, with_IRT=1, IRT_initialization=1, max_epoch=30, input='../test/frames', processed='../test/result', output='../test/consistent')
# ../test/consistent//colorization_IRT1_initial1/frames ../test/frames ../test/result
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# (180, 320, 3) (180, 320, 3)
# ...

# %%
# frames = [f"predictions_{str(i).zfill(5)}.jpg" for i in range(205)]
frames = [f"out_main_{str(i).zfill(5)}.jpg" for i in range(205)]
# for i in [10, 15, 20, 25, 30, 35, 40, 45, 50]:
for i in [30]:
    frames_path = f"../test/consistent/colorization_IRT1_initial1/frames/00{i}"
    video_name = f"../test/test{i}.mp4"
    convert_frames_to_video(frames_path, video_name, frames)
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
